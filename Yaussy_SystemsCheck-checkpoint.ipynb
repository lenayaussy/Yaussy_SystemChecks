# %% [markdown]
# # I hope to learn how data can be used to better understand people, technology, and the world around us.

# %% [markdown]
# ## I want to become more comfortable working with data and learn how to present it in ways that are clear and meaningful.

# %% [markdown]
# **I also want to get better at turning data into something meaningful** *and easy for other people to understand.*

# %% [markdown]
# ![Tech Picture](https://imgproxy.domestika.org/unsafe/s:1200:630/rs:fill/ex:true/el:true/plain/src://blog-post-open-graph-covers/000/011/439/11439-original.jpg?1692707330)

# %%
x = 3

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
print("I am excited for this class!!")
# Out:
# I am excited for this class!!

# %%
def subtractNumbers(a, b):
    result=a-b
    return result
subtractNumbers(10, 4)
# Out:
# 6
